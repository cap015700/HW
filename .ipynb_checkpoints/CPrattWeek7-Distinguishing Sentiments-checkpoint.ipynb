# %% [markdown]
# ### Observations
# -  BBC has the highest overall sentiment
# -  NY Times has the lowest overall sentiment
# -  CBS seems to have the most neutral sentiment

# %%
import os
import tweepy
import json
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
file_name = "api_keys.json"
data = api_keys = json.load(open("c:/Users/charl/Desktop/APIKeys/api_keys.json"))

gkey = data['google_places_api_key']
consumer_key = data['twitter_consumer_key']
consumer_secret = data['twitter_consumer_secret']
access_token = data['twitter_access_token']
access_token_secret = data['twitter_access_token_secret']

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# %%
news_networks = ['@BBC', '@CNN', '@CBS', '@FoxNews', '@NYT']

# %%
news = []
account =[]
date = []
text =[]
tweet_number=[]
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
for network in news_networks:
    public_tweets = api.search(network, count=100, result_type="recent")
    for tweet in public_tweets['statuses']:
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        news.append(network)
        account.append(tweet['user']['name'])
        date.append(tweet['created_at'])
        text.append(tweet['text'])
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

# %%
df = pd.DataFrame({
    "Network":news,
    "User":account,
    "Date":date,
    "Text":text,
    "Positive":positive_list,
    "Neutral":neutral_list,
    "Negative":negative_list,
    "Compound":compound_list,
})
df = df[['Network','User','Date','Text','Positive','Neutral','Negative','Compound']]

# %%
df.to_csv("Twitter_Sentiments.csv")
df = df.sort_values("Date")
df
# Out:
#       Network                              User  \
# 499      @NYT                 Trump 2020 vision
# 498      @NYT                    Roberta Butler
# 497      @NYT                Chakradhar Mohanta
# 496      @NYT               🎗nthropologies||☆||
# 495      @NYT             #ParklandCrisisActors
# 494      @NYT                 N McKeel Petrella
# 493      @NYT              Jose Tijam, PMP, CSM
# 492      @NYT                    thehalpernteam
# 491      @NYT                    thehalpernteam
# 490      @NYT                    thehalpernteam
# 489      @NYT                    thehalpernteam
# 488      @NYT                        Sean Sasso
# 487      @NYT                        Sean Sasso
# 486      @NYT                        Sean Sasso
# 485      @NYT                        Sean Sasso
# 484      @NYT                        Sean Sasso
# 483      @NYT                    thehalpernteam
# 482      @NYT                         FusionDOJ
# 481      @NYT                            cjland
# 480      @NYT                         AVST-CX-E
# 479      @NYT                     Shirley Moore
# 478      @NYT                      Bruce Wolman
# 477      @NYT                        Sean Sasso
# 476      @NYT                        Sean Sasso
# 475      @NYT                    thehalpernteam
# 474      @NYT                    thehalpernteam
# 473      @NYT              Jose Tijam, PMP, CSM
# 472      @NYT                           Hugoden
# 471      @NYT                        SquareOne™
# 470      @NYT                        No pasarán
# ..        ...                               ...
# 114      @CNN                       Cloudie Co.
# 316  @FoxNews                    Reggie-doodley
# 109      @CNN                            Raptor
# 108      @CNN                    Alex Schreiner
# 110      @CNN                            Marcus
# 111      @CNN                               677
# 107      @CNN                       🇺🇸Brenda 🇺🇸
# 106      @CNN                       ST4C Health
# 105      @CNN                               kat
# 313  @FoxNews                      Emma McLaury
# 472  @Nuke_The_Liars @ds13_manon An media manipulat...     0.137    0.758
# 471  Fosun Triumphs in Bidding War for Lanvin, Trou...     0.151    0.503
# 470  @exercitooficial @nyt @TheYoungTurks @OEA_ofic...     0.000    1.000
# ..                                                 ...       ...      ...
# 114  RT @CNN: President Trump says he's thinking ab...     0.000    1.000
# 316  @FoxNews If so then please look at Melania's p...     0.244    0.756
# 109  @CNN i haven't heard from a single teacher tha...     0.139    0.759
# 108  RT @CNN: NRA spokeswoman: "Many in legacy medi...     0.258    0.646
# 110  RT @CNN: Florida school shooting survivor on W...     0.102    0.898
# 111  @CNNPolitics I don’t know what to believe, wer...     0.000    1.000
# 107  RT @MarkDice: @CNN Stop harassing people at th...     0.000    0.600
# 106  RT @CNN: The rise in abuse of prescription pai...     0.000    0.717
# 105  RT @TearsInHeaven09: Why is @cnn and @msnbc ai...     0.000    0.761
# 313  Exactly.   And the propaganda that @FoxNews is...     0.000    0.909
# 314  @JTrott @MaryGodfree @robertjeffress @realDona...     0.000    1.000
# 315  @FoxNews @christuckerreal Rush Hour 4: I neede...     0.000    1.000
# 104  RT @CNN: President Trump defends the NRA, sayi...     0.154    0.846
# 311  @FoxNews @JesseBWatters @POTUS How about this ...     0.133    0.867
# 312  RT @FoxNews: .@AndrewGillum: "I am extremely o...     0.231    0.769
# 103  @RSthePit @traceyinvanc @youngfung5 @RidgewayG...     0.084    0.782
# 310  @markl5757 @FoxNews Exactly. I turn my station...     0.000    0.800
# 309      @FoxNews like arming teachers? Please people!     0.560    0.440
# 308  @FoxNews @EricTrump I think I'll put a hot pok...     0.000    1.000
# 101  RT @realDonaldTrump: I never said “give teache...     0.091    0.797
# 102  RT @JewhadiTM: .@DLoesch on @CNN Townhall #Stu...     0.148    0.852
# 100  RT @surfermom77: #FakeNews @CNN done it again ...     0.000    0.880
# 307  @FoxNews @NRA Boy, I guess I really was right....     0.000    0.854
# 305  RT @TheDailyShow: CRISIS ACTOR EXPOSED: Why is...     0.000    0.427
# 306  RT @FoxNews: Wayne LaPierre: "Our country is u...     0.000    1.000
# 303  @1776Stonewall @FoxNews They're paying Juan to...     0.000    0.569
# 304  @FoxNews @EricTrump The runt of the litter get...     0.000    1.000
# 301  RT @Mrsbowmanocsa: @FoxNews @POTUS I am a teac...     0.000    1.000
# 302  RT @FoxNews: .@NRA's Wayne LaPierre: "Any Amer...     0.000    1.000
# 300  @FoxNews @nyuniversity Seeeeeeeeeeeeeeeeeeeeee...     0.090    0.910
#
#      Negative  Compound
# 499     0.117   -0.1531
# 498     0.000    0.4404
# 497     0.151   -0.4939
# 496     0.262   -0.5994
# 495     0.217   -0.5574
# 494     0.200   -0.3612
# 493     0.097   -0.1280
# 492     0.000    0.0000
# 491     0.000    0.0000
# 490     0.000    0.0000
# 489     0.000    0.0000
# 488     0.000    0.0000
# 487     0.000    0.0000
# 486     0.000    0.0000
# 485     0.000    0.0000
# 484     0.000    0.0000
# 483     0.000    0.0000
# 482     0.100    0.6177
# 481     0.000    0.0000
# 480     0.000    0.0000
# 479     0.156   -0.5719
# 478     0.000    0.0000
# 477     0.000    0.0000
# 476     0.000    0.0000
# 475     0.000    0.0000
# 474     0.000    0.0000
# 473     0.289   -0.5994
# 472     0.104    0.1779
# 471     0.347   -0.5994
# 470     0.000    0.0000
# ..        ...       ...
# 114     0.000    0.0000
# 316     0.000    0.3774
# 109     0.101    0.2263
# 108     0.095    0.7430
# 110     0.000    0.3612
# 111     0.000    0.0000
# 107     0.400   -0.7177
# 106     0.283   -0.7964
# 105     0.239   -0.6788
# 313     0.091   -0.2500
# 314     0.000    0.0000
# 315     0.000    0.0000
# 104     0.000    0.4939
# 311     0.000    0.3818
# 312     0.000    0.7178
# 103     0.134   -0.2263
# 310     0.200   -0.5423
# 309     0.000    0.6239
# 308     0.000    0.0000
# 101     0.112   -0.1531
# 102     0.000    0.5106
# 100     0.120   -0.3818
# 307     0.146   -0.3400
# 305     0.573   -0.9015
# 306     0.000    0.0000
# 303     0.431   -0.6486
# 304     0.000    0.0000
# 301     0.000    0.0000
# 302     0.000    0.0000
# 300     0.000    0.1511
#
# [500 rows x 8 columns]

# %%
counter1=0
counter2=0
counter3=0
counter4=0
counter5=0

for index, row in df.iterrows():
    if (row["Network"]=="@CNN"):
        counter1 = counter1+1
        CNN = plt.scatter(counter1,row["Compound"],c ='r',marker="o")
    if (row["Network"]=="@NYT"):
        counter2 = counter2+1
        NYT = plt.scatter(counter2,row["Compound"],c ='y',marker="o")
    if (row["Network"]=="@FoxNews"):
        counter3 = counter3+1
        FOX = plt.scatter(counter3,row["Compound"],c ='b',marker="o")
    if (row["Network"]=="@BBC"):
        counter4 = counter4+1
        BBC = plt.scatter(counter4,row["Compound"],c ='cyan',marker="o")
    if (row["Network"]=="@CBS"):
        counter5 = counter5+1
        CBS = plt.scatter(counter5,row["Compound"],c ='g',marker="o")
        
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.title("Sentiment Analysis of Media Tweets (2/22)")
plt.legend(handles = [CNN,BBC,NYT,FOX,CBS], labels = ["CNN","BBC","NYT","FOX","CBS"], loc='center left', bbox_to_anchor=(1, 0.5))

sns.set
plt.show()

# %%
new_df = pd.DataFrame(df.groupby("Network")["Compound"].mean())
new_df
# Out:
#           Compound
# Network
# @BBC      0.055869
# @CBS      0.017337
# @CNN     -0.028403
# @FoxNews -0.023122
# @NYT     -0.044712

# %%
x_axis = np.arange(len(new_df["Compound"]))
compound_score = new_df["Compound"]
tick_locations = [value+0.4 for value in x_axis]
plt.xticks(tick_locations, ["BBC", "CBS", "CNN", "FOX", "NYT"])
plt.bar(x_axis, compound_score, color = ['b','g','m','c','y'], alpha=0.5, align="edge")
plt.xlabel("Networks")
plt.ylabel("Tweet Polarity")
plt.title("Overall Media Sentiment Based on Twitter (2/22/2018)")
sns.set()
plt.show()
